# %% [markdown]
# <a href="https://colab.research.google.com/github/Syaroful/syaroful-pcvk-semester-5/blob/main/syaroful_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Muhamad Syaroful Anam
# 2141720108
# No. Absen 17

import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# list of image url
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# how to show them
for url in urls:
  image = io.imread(url) #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color to rgb
  final_frame = cv.hconcat((image, image_2)) # concatenate image
  cv2_imshow(final_frame) # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# create horizontal line in the center image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in  range (tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255] # vertical line

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)


image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255))

cv.line(image_3, (lebar,0), (0, tinggi), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line_width = 100
cv.line(image_3, (100, 200), (100 + line_width,200), (255,255,255), 1) #panjang garis 100

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.rectangle(image_3, (100, 100), (200,200), (255,255,255), -1) # kotak

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Tugas menutupi KTP
#
# Kelompok 10 :
# 1.   Agilar Gumilar
# 2.   Muhamad Syaroful Anam

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Kuliah/Semester_5/PCVK/image/ktp-soppeng.jpeg'
ktp_img = cv.imread(path)
ktp_img = cv.cvtColor(ktp_img, cv.COLOR_BGR2RGB)
plt.imshow(ktp_img)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Alasan penggunaan konversi warna BGR2RGB pada matplotlib dan tidak perlu konversi pada OpenCV adalah karena perbedaan konvensi warna yang digunakan oleh masing-masing pustaka.
#
# OpenCV:
# - OpenCV adalah pustaka pengolahan gambar dan komputer yang umumnya digunakan dalam pengolahan citra komputer dan visi mesin.
# - OpenCV secara internal mengggunakan format BGR untuk merepresentasikan gambar. Artinya, dalam gambar yang dimuat oleh OpenCV, warna biru disimpan sebagai channel pertama, hijau sebagai channel kedua, dan merah sebagai channel ketiga.
#
# Matplotlib:
# - Matplotlib adalah pustaka visualisasi data yang sering digunakan untuk membuat grafik, plot, dan menampilkan gambar.
# - Matplotlib menggunakan format RGB untuk menampilkan gambar. Artinya, dalam gambar yang ditampilkan menggunakan Matplotlib, warna merah disimpan sebagai channel pertama, hijau sebagai channel kedua, dan biru sebagai channel ketiga.

# %%
ktp_img[160:180, 140:200] = (255, 122, 0) # orange color, covering RT/RW
ktp_img[180:200, 140:190] = (0, 66, 234) # blue color, covering Desa
plt.imshow(ktp_img)
